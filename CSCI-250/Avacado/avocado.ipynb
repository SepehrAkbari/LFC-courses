# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
# from collections import Counter

# %%
os.listdir('../Data')
# Out:
# ['avocado-updated-2020.csv']

# %%
print('a','\r','b')
# Out:
#  b

# %%
df = pd.read_csv('../Data/avocado-updated-2020.csv')
df.head(10)
# Out:
#          date  average_price  total_volume       4046       4225      4770  \
# 0  2015-01-04           1.22      40873.28    2819.50   28287.42     49.90
# 1  2015-01-04           1.79       1373.95      57.42     153.88      0.00
# 2  2015-01-04           1.00     435021.49  364302.39   23821.16     82.15
# 3  2015-01-04           1.76       3846.69    1500.15     938.35      0.00
# 4  2015-01-04           1.08     788025.06   53987.31  552906.04  39995.03
# 5  2015-01-04           1.29      19137.28    8040.64    6557.47    657.48
# 6  2015-01-04           1.01      80034.32   44562.12   24964.23   2752.35
# 7  2015-01-04           1.64       1505.12       1.27    1129.50      0.00
# 8  2015-01-04           1.02     491738.00    7193.87  396752.18    128.82
# 9  2015-01-04           1.83       2192.13       8.66     939.43      0.00
#
#    total_bags  small_bags  large_bags  xlarge_bags          type  year  \
# ...

# %%
df.shape
# Out:
# (33045, 13)

# %%
df.describe()
# Out:
#        average_price  total_volume          4046          4225          4770  \
# count   33045.000000  3.304500e+04  3.304500e+04  3.304500e+04  3.304500e+04
# mean        1.379941  9.683997e+05  3.023914e+05  2.797693e+05  2.148255e+04
# std         0.378972  3.934533e+06  1.301026e+06  1.151052e+06  1.001607e+05
# min         0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%         1.100000  1.511895e+04  7.673100e+02  2.712470e+03  0.000000e+00
# 50%         1.350000  1.291170e+05  1.099477e+04  2.343600e+04  1.780900e+02
# 75%         1.620000  5.058285e+05  1.190219e+05  1.352389e+05  5.096530e+03
# max         3.250000  6.371614e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          total_bags    small_bags    large_bags   xlarge_bags          year
# count  3.304500e+04  3.304500e+04  3.304500e+04  3.304500e+04  33045.000000
# mean   3.646735e+05  2.501980e+05  1.067329e+05  7.742585e+03   2017.460887
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33045 entries, 0 to 33044
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           33045 non-null  object
#  1   average_price  33045 non-null  float64
#  2   total_volume   33045 non-null  float64
#  3   4046           33045 non-null  float64
#  4   4225           33045 non-null  float64
#  5   4770           33045 non-null  float64
#  6   total_bags     33045 non-null  float64
#  7   small_bags     33045 non-null  float64
#  8   large_bags     33045 non-null  float64
#  9   xlarge_bags    33045 non-null  float64
#  10  type           33045 non-null  object
#  11  year           33045 non-null  int64
#  12  geography      33045 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 3.3+ MB

# %%
d17 = df[df.year==2017]
data = d17[ d17.geography=='Chicago']
data.head(10)
# Out:
#              date  average_price  total_volume       4046       4225  \
# 11247  2017-01-01           1.15     803348.87   87695.70  531287.44
# 11248  2017-01-01           1.34      36915.87      36.67   34076.57
# 11355  2017-01-08           1.16     822522.24   79629.99  499835.88
# 11356  2017-01-08           1.81      28099.34      70.76   23893.31
# 11463  2017-01-15           1.23     776820.81   78836.36  480071.92
# 11464  2017-01-15           1.85      38542.50      78.31   34378.08
# 11571  2017-01-22           1.21     845065.66  120093.41  497235.79
# 11572  2017-01-22           1.51      47561.03      52.69   43587.09
# 11679  2017-01-29           1.10     830499.38   86213.34  511365.64
# 11680  2017-01-29           1.51      44735.40      87.33   40554.73
#
#             4770  total_bags  small_bags  large_bags  xlarge_bags  \
# 11247  114647.36    69718.37    63550.62     1078.38      5089.37
# 11248       0.00     2802.63     2802.63        0.00         0.00
# ...

# %%
data.shape
# Out:
# (106, 13)

# %%
region_list=list(df.geography.unique())
region_list
# Out:
# ['Albany',
#  'Atlanta',
#  'Baltimore/Washington',
#  'Boise',
#  'Boston',
#  'Buffalo/Rochester',
#  'California',
#  'Charlotte',
#  'Chicago',
#  'Cincinnati/Dayton',
#  'Columbus',
#  'Dallas/Ft. Worth',
#  'Denver',
#  'Detroit',
#  'Grand Rapids',
#  'Great Lakes',
#  'Harrisburg/Scranton',
#  'Hartford/Springfield',
#  'Houston',
#  'Indianapolis',
#  'Jacksonville',
#  'Las Vegas',
#  'Los Angeles',
#  'Louisville',
#  'Miami/Ft. Lauderdale',
#  'Midsouth',
#  'Nashville',
#  'New Orleans/Mobile',
#  'New York',
#  'Northeast',
#  'Northern New England',
#  'Orlando',
#  'Philadelphia',
#  'Phoenix/Tucson',
#  'Pittsburgh',
#  'Plains',
#  'Portland',
#  'Raleigh/Greensboro',
#  'Richmond/Norfolk',
#  'Roanoke',
#  'Sacramento',
#  'San Diego',
#  'San Francisco',
#  'Seattle',
#  'South Carolina',
#  'South Central',
#  'Southeast',
#  'Spokane',
#  'St. Louis',
#  'Syracuse',
#  'Tampa',
#  'Total U.S.',
#  'West',
#  'West Tex/New Mexico']

# %%
average_price=[]

for i in region_list:
    x=df[df.geography==i]
    region_average=sum(x.average_price)/len(x)
    average_price.append(region_average)

average_price
# Out:
# [1.491748366013073,
#  1.3033006535947709,
#  1.4748202614379067,
#  1.4372385620915031,
#  1.5363071895424845,
#  1.3956862745098024,
#  1.4459150326797388,
#  1.5492810457516344,
#  1.5242647058823546,
#  1.2378431372549026,
#  1.2202287581699358,
#  1.0761601307189557,
#  1.2630882352941188,
#  1.2538725490196079,
#  1.446486928104574,
#  1.3105718954248364,
#  1.3858496732026147,
#  1.7607516339869276,
#  1.0757516339869277,
#  1.259607843137256,
#  1.387826797385623,
#  1.3585294117647044,
#  1.3110130718954258,
#  1.2697712418300666,
#  1.340424836601307,
#  1.3730718954248398,
#  1.2177450980392168,
#  1.2300653594771231,
#  1.6594771241830066,
#  1.5388725490196093,
#  1.4495588235294123,
#  1.3612418300653577,
#  1.5241993464052297,
#  1.2092973856209135,
#  1.3273856209150328,
#  1.3513235294117651,
#  1.4095915032679747,
#  1.544787581699347,
#  1.2487581699346404,
#  1.2338071895424845,
#  1.5846078431372537,
#  1.4561111111111118,
#  1.7599673202614365,
# ...

# %%
df1=pd.DataFrame({'region_list':region_list,'average_price':average_price})
df1.head()
# Out:
#             region_list  average_price
# 0                Albany       1.491748
# 1               Atlanta       1.303301
# 2  Baltimore/Washington       1.474820
# 3                 Boise       1.437239
# 4                Boston       1.536307

# %%
new_index = df1.average_price.sort_values(ascending=False).index.values
sorted_data = df1.reindex(new_index)

plt.figure(figsize=(15,10))
plt.bar(sorted_data.region_list,sorted_data.average_price)
# ax=sns.barplot(x=sorted_data.region_list,y=sorted_data.average_price,palette='rocket')

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Average Price of Avocado According to Region')
plt.show()

# %%
x = df.average_price
y = df.total_volume
df2 = pd.DataFrame({'price':x,'volume':y})
df2.head(5)
# Out:
#    price     volume
# 0   1.22   40873.28
# 1   1.79    1373.95
# 2   1.00  435021.49
# 3   1.76    3846.69
# 4   1.08  788025.06

# %%
plt.scatter(x,y)
plt.xlabel('Average Price')
plt.ylabel('Total Volume')
plt.show()
