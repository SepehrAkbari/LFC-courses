# %% [markdown]
# # Exam 2

# %%
import numpy as np
points = np.random.uniform(5, 10, size=(100, 2))
points
# Out:
# array([[8.07916412, 8.87883144],
#        [5.53023699, 6.46901245],
#        [9.44884604, 8.46945589],
#        [5.24863873, 5.97827613],
#        [7.1130628 , 7.67209425],
#        [7.62656618, 8.14880748],
#        [8.30537985, 8.84675395],
#        [8.24642561, 6.03668496],
#        [6.96081521, 5.37323872],
#        [8.6883757 , 7.22949175],
#        [9.46765167, 6.73834515],
#        [6.54503453, 7.40190622],
#        [9.22289158, 6.21948196],
#        [9.65479128, 6.68245964],
#        [7.7779662 , 9.46934038],
#        [9.62645765, 9.7868109 ],
#        [8.27622557, 7.98408728],
#        [8.20974564, 7.85281953],
#        [9.13484374, 6.98820251],
#        [8.91867924, 6.84154718],
#        [7.25279289, 7.26140325],
#        [5.4597908 , 8.25686351],
#        [9.73400545, 6.76750098],
#        [8.16482933, 7.76857378],
#        [6.08715995, 6.13916304],
#        [9.7673319 , 8.50125385],
#        [9.32521553, 8.63002083],
#        [8.96074236, 7.91005352],
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=200)
clf.fit(traindata, trainlabels)

# %%
count = (healthdata['age'] >= 60).sum()

# %%
d = {
    'age': 23,
    'cholesterol': 1,
    'blood_pressure': 4
}

for v in d: 
    print(v)
# Out:
# age
# cholesterol
# blood_pressure
