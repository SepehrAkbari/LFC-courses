# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage import io, data, color, transform

# %%
image = data.astronaut()
io.imshow(image)
# Out:
# /var/folders/4z/1s07dvg55sq1ks6sghlxv2rh0000gn/T/ipykernel_92305/868094330.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(image)

# %%
io.imshow(image[:,:,2])
# Out:
# /var/folders/4z/1s07dvg55sq1ks6sghlxv2rh0000gn/T/ipykernel_92305/3302698538.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(image[:,:,2])

# %%
image2 = io.imread(example.jpg) # example.jpg does not exist, this is just an example
plt.imshow(image2)
print(image2.shape)
